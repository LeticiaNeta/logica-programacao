# %% [markdown]
# # Operadores Aritméticos

# %%
# Adição
10 + 2
# Out:
# 12

# %%
# Subtração
10 - 2
# Out:
# 8

# %%
# Multiplicação
10 * 2
# Out:
# 20

# %%
# Divisão - Número real
10 / 2
# Out:
# 5.0

# %%
# Divisão Inteira - Número Inteiro
10 // 2
# Out:
# 5

# %%
# Resto de divisão
10 % 2
# Out:
# 0

# %%
# Potenciação
10 ** 2
# Out:
# 100

# %% [markdown]
# # Operadores Relacionais

# %%
# Menor
10 < 2
# Out:
# False

# %%
# Menor ou Igual
10 <= 2
# Out:
# False

# %%
# Maior
10 > 2
# Out:
# True

# %%
# Maior ou Igual
10 >= 2
# Out:
# True

# %%
# Igual
7 == 7
# Out:
# True

# %%
# Diferente
7 !=7
# Out:
# False

# %% [markdown]
# # Tabela Verdade

# %% [markdown]
# ## And

# %%
print(2 > 1 and 5 < 8)
# Out:
# True

# %%
print(2>1 and 5>8)
# Out:
# False

# %%
print(2<1 and 5<8)
# Out:
# False

# %%
print(2<1 and 5>8)
# Out:
# False

# %% [markdown]
# ## Or

# %%
print(2>1 or 5<8)
# Out:
# True

# %%
print(2>1 or 5>8)
# Out:
# True

# %%
print(2<1 or 5<8)
# Out:
# True

# %%
print(2<1 or 5>8)
# Out:
# False

# %% [markdown]
# ## Not

# %%
print(not 2>1)
# Out:
# False

# %%
not 1<2
# Out:
# False
