# %% [markdown]
# ## Condicional

# %%
#IF
if 5 > 10:
  print('Verdade')

# %%
# If/else

num1 = 10
num2 = 5
if num1 > num2:
  print('O num1 é o maior número')

else:
  print('O num2 é o maior número')
# Out:
# O num1 é o maior número

# %%
# If / Elif / Else

num1 = 15
num2 = 15
if num1 > num2:
  print('O num1 é o maior número')
elif num1 < num2:
  print('O num2 é o maior número')
else:
  print('Os dois são iguais')
# Out:
# Os dois são iguais

# %% [markdown]
# ## Condicional com operadores lógicos

# %%
num1 = 10
num2 = 15
num3 = 30
if (num1 > num2) and (num1 > num3):
  print('O num1 é o maior número')
elif (num2 > num1) and (num2 > num3):
  print ('O num2 é o maior número')
else:
  print('O num3 é o maior número')
# Out:
# O num3 é o maior número

# %% [markdown]
# ### Codificando

# %%
nota1 = float(input('Digite a nota1: '))
nota2 = float(input('Digite a nota2: '))
nota3 = float(input('Digite a nota3: '))

media_aluno = (nota1 + nota2 + nota3) / 3

if media_aluno >= 7:
  print(f'Aluno aprovado, sua média é: {media_aluno:.2f}')
else:
  print(f'Aluno reprovado, sua média é: {media_aluno: .2f}')
# Out:
# Digite a nota1: 5
# Digite a nota2: 3
# Digite a nota3: 6
# Aluno reprovado, sua média é:  4.67

# %%
velocidade = input("Velocidade medida:")

velocidade = float(velocidade)
x = velocidade
y = 80

if velocidade > 80:
  porcentagem_excedida = ((x / y) - 1) * 100
  print(f'Multado, ultrapassou o limite de velocidade em {porcentagem_excedida: .2f}%')
  if porcentagem_excedida <=20:
    print('Multa Leve')
  elif porcentagem_excedida <=40:
    print('Multa Média')
  else:
    print('Multa Grave')

elif velocidade <= 80:
    print('Velocidade dentro do limite')
# Out:
# Velocidade medida:100
# Multado, ultrapassou o limite de velocidade em  25.00%
# Multa Média

# %%
hora = int(input('Digite a hora atual (0 a 23):'))

if 0 <= hora <=11:
  print('Bom dia')
elif 12 <= hora <=17:
  print('Boa tarde')
elif 18 <= hora <=23:
  print('Boa noite')

else:
  print('Hora inválida')
# Out:
# Digite a hora atual (0 a 23):25
# Hora inválida

# %%
Temperatura = float(input('Digite a temperatura atual em °C:'))

if 0 <= Temperatura <=10:
  print('Muito Frio!')
elif 11 <= Temperatura <=25:
  print('Temperatura Agradável!')
else:
  print('Está calor!')
# Out:
# Digite a temperatura atual em °C:5
# Muito Frio!
