# %% [markdown]
# # Variáveis

# %%
# Nome da variável é "x" que armazena o valor de 10 em um espaço de memória.
x=10

print(x) # utilizar referência no nome atribuído
# Out:
# 10

# %% [markdown]
# # Visualização de Variáveis e textos

# %%
print('Conhecendo o comando Print')

x = 8
print(x)
# Out:
# Conhecendo o comando Print
# 8

# %%
y = 10
soma = x + y
print(soma)
# Out:
# 18

# %%
nome = "Rodrigo Rebouças"
print(nome)
# Out:
# Rodrigo Rebouças

# %% [markdown]
# ### Concatenação

# %%
x = 5
print('O valor de x é: ' , x)
# Out:
# O valor de x é:  5

# %%
print('O valor de x é', x, 'e o dobro é', x*2)
# Out:
# O valor de x é 5 e o dobro é 10

# %%
print('Eu', nome, 'tirei', x, 'na prova de Python')
# Out:
# Eu Rodrigo Rebouças tirei 5 na prova de Python

# %%
y = 10; z = 20 + x - y

print('Declarar várias vaviáveis na mesma linha', y, z)
# Out:
# Declarar várias vaviáveis na mesma linha 10 15

# %% [markdown]
# ### Type

# %%
x = 10
type(x)
print('x', type(x))

nome = 'Rodrigo'
print('nome', type (nome))

num = '100'
num_convert = int(num)     #Converter variável
print('num' , type (num))
print('num_convert', type (num_convert))

num_float = float(num)
print('num_float', num_float)
# Out:
# x <class 'int'>
# nome <class 'str'>
# num <class 'str'>
# num_convert <class 'int'>
# num_float 100.0

# %% [markdown]
# ### Input
#
# * Armazenar a informação digitada pelo usuário em uma variável
# * O dado armazenado sempre será um texto

# %%
nome = input('Digite o seu:')  #Aguardar o usuário digitar algo e dps rodar código
print('Olá,' , nome)
# Out:
# Digite o seu nome:Letícia
# Olá, Letícia

# %%
idade = input('Digite sua idade:')
print(type(idade)) #Isso vai me mostrar a classe - Ou seja: <class 'str'>
# Out:
# Digite sua idade:22
# <class 'str'>

# %%
valor = input('Digite uma nota')
print(nome, 'sua nota foi', valor)
# Out:
# Digite uma nota8,5
# Letícia sua nota foi 8,5

# %%
valor = input('Digite o valor do produto: ')
print(valor)
# Out:
# Digite o valor do produto: 100
# 100

# %%
desconto = valor - 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2171237004.py in <cell line: 0>()
# ----> 1 desconto = valor - 5
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
valor_convet = int(valor)      #Usa-se valor_convet quando você for usar esse mesmo valor em outros lugares do seu código
desconto = valor_convet - 5
print(desconto)
# Out:
# 95

# %%
desconto = int(valor) - 5
print(desconto)
# Out:
# 95
