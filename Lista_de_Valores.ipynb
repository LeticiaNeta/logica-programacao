# %% [markdown]
# #Listas, tuplas e dicionários

# %%
# Lista
[1,2,3,4]
# Out:
# [1, 2, 3, 4]

# %%
# Tupla
(1,2,3,4)
# Out:
# (1, 2, 3, 4)

# %%
# Dicionário
{'num1': 1, 'num2': 2}
# Out:
# {'num1': 1, 'num2': 2}

# %% [markdown]
# ## Lista

# %%
lista = [5, 'Letícia', 8.9]

# %%
type(lista)
# Out:
# list

# %%
lista.append("Augusto")  # Adicionar um elemento na lista

# %%
print(lista)
print(lista[1])
# Out:
# [5, 'Letícia', 8.9, 'Augusto', 'Augusto']
# Letícia

# %% [markdown]
# ## Tupla

# %%
tupla = (5, 'Letícia', 8.9)

# %%
type(tupla)
# Out:
# tuple

# %%
tupla.append("Augusto")  # Tupla não pode ser alterada
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3021230460.py in <cell line: 0>()
# ----> 1 tupla.append("Augusto")  # Tupla não pode ser alterada
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
print(tupla)
# Out:
# (5, 'Letícia', 8.9)

# %% [markdown]
# ## Dicionário

# %%
dicionario = {'nome':'Letícia','Cidade': 'São Bernardo do Campo'}

# %%
type(dicionario)
# Out:
# dict

# %%
print(dicionario)
# Out:
# {'nome': 'Letícia', 'Cidade': 'São Bernardo do Campo'}

# %%
print(dicionario["nome"])
# Out:
# Letícia

# %%
dicionario["ultimo_nome"] = "Neta"

# %%
print(dicionario)
# Out:
# {'nome': 'Letícia', 'Cidade': 'São Bernardo do Campo', 'ultimo_nome': 'Neta'}

# %% [markdown]
# ## Codificando

# %% [markdown]
# ###Listas
#
# Crie um programa que:
#
# Peça ao usuário para digitar 3 frutas (uma por uma).
# Armazene essas frutas em uma lista.
# Depois, exiba todas as frutas digitadas.

# %%
frutas = []

for i in range (3):
  fruta = input(f'Digite o nome da fruta {i+1}')
  frutas.append(fruta)

  print('As futas digitadas foram:', frutas)
# Out:
# Digite o nome da fruta 1Banana
# As futas digitadas foram: ['Banana']
# Digite o nome da fruta 2Morango
# As futas digitadas foram: ['Banana', 'Morango']
# Digite o nome da fruta 3Maça
# As futas digitadas foram: ['Banana', 'Morango', 'Maça']

# %% [markdown]
# ### Tuplas
#
# Crie uma tupla com 5 números inteiros e:
# Mostre o maior e o menor número da tupla.
# Mostre a soma de todos os números.

# %%
numeros = (4,8,2,7,1)

print('Maior número:' , max(numeros))
print('Menor número:', min(numeros))
print('Soma total:' , sum(numeros))
# Out:
# Maior número: 8
# Menor número: 1
# Soma total: 22

# %% [markdown]
# ## Dicionário

# %%
pessoa = {}

pessoa["nome"] = input("Digite o nome: ")
pessoa["idade"] = input("Digite a idade: ")
pessoa["cidade"] = input("Digite a cidade: ")

print("Dados completos:", pessoa)
print(f'{pessoa["nome"]} tem {pessoa["idade"]} anos e mora em {pessoa["cidade"]}.')
# Out:
# Digite o nome: Letícia
# Digite a idade: 22
# Digite a cidade: São Paulo
# Dados completos: {'nome': 'Letícia', 'idade': '22', 'cidade': 'São Paulo'}
# Letícia tem 22 anos e mora em São Paulo.
